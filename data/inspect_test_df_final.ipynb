# %%
import pickle
import pathlib

# Adjust the path as needed
data_path = pathlib.Path("test_df_final.pkl")

with open(data_path, "rb") as f:
    df_final, days_list, var_list, ha_config = pickle.load(f)

print("df_final (type):", type(df_final))
print("df_final (head):")
print(df_final.head())
print("\ndays_list (type):", type(days_list))
print("days_list (value):", days_list)
print("\nvar_list (type):", type(var_list))
print("var_list (value):", var_list)
print("\nha_config (type):", type(ha_config))
print("ha_config (value):", ha_config)
# Out:
# df_final (type): <class 'pandas.core.frame.DataFrame'>
# df_final (head):
#                            sensor.power_load_no_var_loads  \
# 2025-03-12 00:00:00+00:00                     1381.538807
# 2025-03-12 00:30:00+00:00                     1398.905167
# 2025-03-12 01:00:00+00:00                     1422.262889
# 2025-03-12 01:30:00+00:00                     3161.899222
# 2025-03-12 02:00:00+00:00                     3207.258167
#
#                            sensor.power_photovoltaics  sensor.p_pv_forecast
# 2025-03-12 00:00:00+00:00                         0.0                 -0.55
# 2025-03-12 00:30:00+00:00                         NaN                   NaN
# 2025-03-12 01:00:00+00:00                         NaN                   NaN
# 2025-03-12 01:30:00+00:00                         NaN                   NaN
# 2025-03-12 02:00:00+00:00                         NaN                   NaN
#
# days_list (type): <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# ...
